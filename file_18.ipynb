# %%
import pandas as pd

# %%
df = pd.read_csv("hospital.csv")

# %%
df
# Out:
#     country  state  county    lat     lng   type  measure  beds  population  \
# 0        AF    NaN     NaN  33.00   65.00  TOTAL  1000HAB   0.5    31161376
# 1        AO    NaN     NaN -12.50   18.50  TOTAL  1000HAB   0.8    19433602
# 2        AL    NaN     NaN  41.00   20.00  TOTAL  1000HAB   2.6     2900401
# 3        AD    NaN     NaN  42.50    1.50  TOTAL  1000HAB   2.5       84463
# 4        AE    NaN     NaN  24.00   54.00  TOTAL  1000HAB   1.1     9141596
# ..      ...    ...     ...    ...     ...    ...      ...   ...         ...
# 194      WS    NaN     NaN -13.58 -172.33  TOTAL  1000HAB   1.0      179727
# 195      YE    NaN     NaN  15.00   48.00  TOTAL  1000HAB   0.7    24473178
# 196      ZA    NaN     NaN -29.00   24.00  TOTAL  1000HAB   2.8    47880601
# 197      ZM    NaN     NaN -15.00   30.00  TOTAL  1000HAB   2.0    13605984
# 198      ZW    NaN     NaN -20.00   30.00  TOTAL  1000HAB   1.7    12894316
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 12 columns):
# country       198 non-null object
# state         0 non-null float64
# county        0 non-null float64
# lat           199 non-null float64
# lng           199 non-null float64
# type          199 non-null object
# measure       199 non-null object
# beds          199 non-null float64
# population    199 non-null int64
# year          199 non-null int64
# source        199 non-null object
# source_url    199 non-null object
# dtypes: float64(5), int64(2), object(5)
# memory usage: 18.8+ KB

# %%
mask= df["year"]== 2005
df[mask]
# Out:
#     country  state  county    lat     lng   type  measure  beds  population  \
# 1        AO    NaN     NaN -12.50   18.50  TOTAL  1000HAB   0.8    19433602
# 37       CG    NaN     NaN  -1.00   15.00  TOTAL  1000HAB   1.6     3622775
# 129      NE    NaN     NaN  16.00    8.00  TOTAL  1000HAB   0.3    13624467
# 172      TD    NaN     NaN  15.00   19.00  TOTAL  1000HAB   0.4    10096633
# 194      WS    NaN     NaN -13.58 -172.33  TOTAL  1000HAB   1.0      179727
# 196      ZA    NaN     NaN -29.00   24.00  TOTAL  1000HAB   2.8    47880601
#
#      year      source                                    source_url
# 1    2005  world-bank  https://datahub.io/world-bank/sh.med.beds.zs
# 37   2005  world-bank  https://datahub.io/world-bank/sh.med.beds.zs
# 129  2005  world-bank  https://datahub.io/world-bank/sh.med.beds.zs
# 172  2005  world-bank  https://datahub.io/world-bank/sh.med.beds.zs
# 194  2005  world-bank  https://datahub.io/world-bank/sh.med.beds.zs
# ...

# %%
mask1= df["beds"]> 2.5
df[mask1]
# Out:
#     country  state  county    lat     lng   type  measure   beds  population  \
# 2        AL    NaN     NaN  41.00   20.00  TOTAL  1000HAB   2.60     2900401
# 5        AR    NaN     NaN -34.00  -64.00  TOTAL  1000HAB   4.70    41733271
# 6        AM    NaN     NaN  40.00   45.00  TOTAL  1000HAB   3.90     2884229
# 8        AU    NaN     NaN -27.00  133.00  TOTAL  1000HAB   3.90    22031750
# 9        AT    NaN     NaN  47.33   13.33  TOTAL  1000HAB   7.60     8391643
# ..      ...    ...     ...    ...     ...    ...      ...    ...         ...
# 187      US    NaN     NaN  38.00  -97.00  TOTAL  1000HAB   2.90   311556874
# 188      UZ    NaN     NaN  41.00   64.00  TOTAL  1000HAB   4.40    28562400
# 189      VC    NaN     NaN  13.25  -61.20  TOTAL  1000HAB   5.20      108435
# 191      VI    NaN     NaN  18.33  -64.83  TOTAL  1000HAB  18.68      108095
# 196      ZA    NaN     NaN -29.00   24.00  TOTAL  1000HAB   2.80    47880601
#
# ...

# %%
mask2= df["year"] != 2005
df[mask2]
# Out:
#     country  state  county   lat    lng   type  measure  beds  population  \
# 0        AF    NaN     NaN  33.0   65.0  TOTAL  1000HAB   0.5    31161376
# 2        AL    NaN     NaN  41.0   20.0  TOTAL  1000HAB   2.6     2900401
# 3        AD    NaN     NaN  42.5    1.5  TOTAL  1000HAB   2.5       84463
# 4        AE    NaN     NaN  24.0   54.0  TOTAL  1000HAB   1.1     9141596
# 5        AR    NaN     NaN -34.0  -64.0  TOTAL  1000HAB   4.7    41733271
# ..      ...    ...     ...   ...    ...    ...      ...   ...         ...
# 192      VN    NaN     NaN  16.0  106.0  TOTAL  1000HAB   2.0    87967651
# 193      VU    NaN     NaN -16.0  167.0  TOTAL  1000HAB   1.7      224704
# 195      YE    NaN     NaN  15.0   48.0  TOTAL  1000HAB   0.7    24473178
# 197      ZM    NaN     NaN -15.0   30.0  TOTAL  1000HAB   2.0    13605984
# 198      ZW    NaN     NaN -20.0   30.0  TOTAL  1000HAB   1.7    12894316
#
#      year      source                                    source_url
# ...

# %%
mask4=df["lat"]> 15.0

# %%
mask5=df["lng"]> 15.0

# %%
df[ mask4 & mask5]
# Out:
#     country  state  county   lat    lng   type  measure  beds  population  \
# 0        AF    NaN     NaN  33.0   65.0  TOTAL  1000HAB   0.5    31161376
# 2        AL    NaN     NaN  41.0   20.0  TOTAL  1000HAB   2.6     2900401
# 4        AE    NaN     NaN  24.0   54.0  TOTAL  1000HAB   1.1     9141596
# 6        AM    NaN     NaN  40.0   45.0  TOTAL  1000HAB   3.9     2884229
# 10       AZ    NaN     NaN  40.5   47.5  TOTAL  1000HAB   4.7     9295784
# ..      ...    ...     ...   ...    ...    ...      ...   ...         ...
# 176      TM    NaN     NaN  40.0   60.0  TOTAL  1000HAB   4.0     5267900
# 181      TR    NaN     NaN  39.0   35.0  TOTAL  1000HAB   2.5    73443863
# 185      UA    NaN     NaN  49.0   32.0  TOTAL  1000HAB   9.0    45593300
# 188      UZ    NaN     NaN  41.0   64.0  TOTAL  1000HAB   4.4    28562400
# 192      VN    NaN     NaN  16.0  106.0  TOTAL  1000HAB   2.0    87967651
#
#      year      source                                    source_url
# ...

# %%
df[df["lat"].isin([12.0,15.0,19.0])]
# Out:
#     country  state  county   lat     lng   type  measure  beds  population  \
# 50       DO    NaN     NaN  19.0  -70.67  TOTAL  1000HAB   1.7     9813210
# 54       ER    NaN     NaN  15.0   39.00  TOTAL  1000HAB   0.7     3213972
# 68       GW    NaN     NaN  12.0  -15.00  TOTAL  1000HAB   1.0     1483921
# 76       HN    NaN     NaN  15.0  -86.50  TOTAL  1000HAB   0.7     8640691
# 78       HT    NaN     NaN  19.0  -72.42  TOTAL  1000HAB   1.3     9495328
# 155      SD    NaN     NaN  15.0   30.00  TOTAL  1000HAB   0.8    36193783
# 172      TD    NaN     NaN  15.0   19.00  TOTAL  1000HAB   0.4    10096633
# 174      TH    NaN     NaN  15.0  100.00  TOTAL  1000HAB   2.1    67195028
# 195      YE    NaN     NaN  15.0   48.00  TOTAL  1000HAB   0.7    24473178
#
#      year      source                                    source_url
# 50   2011  world-bank  https://datahub.io/world-bank/sh.med.beds.zs
# 54   2011  world-bank  https://datahub.io/world-bank/sh.med.beds.zs
# ...

# %%
df[df["country"].isnull()]
# Out:
#     country  state  county   lat   lng   type  measure  beds  population  \
# 128     NaN    NaN     NaN -22.0  17.0  TOTAL  1000HAB   2.7     2081044
#
#      year      source                                    source_url
# 128  2009  world-bank  https://datahub.io/world-bank/sh.med.beds.zs

# %%
 df[df["country"].notnull()]
# Out:
#     country  state  county    lat     lng   type  measure  beds  population  \
# 0        AF    NaN     NaN  33.00   65.00  TOTAL  1000HAB   0.5    31161376
# 1        AO    NaN     NaN -12.50   18.50  TOTAL  1000HAB   0.8    19433602
# 2        AL    NaN     NaN  41.00   20.00  TOTAL  1000HAB   2.6     2900401
# 3        AD    NaN     NaN  42.50    1.50  TOTAL  1000HAB   2.5       84463
# 4        AE    NaN     NaN  24.00   54.00  TOTAL  1000HAB   1.1     9141596
# ..      ...    ...     ...    ...     ...    ...      ...   ...         ...
# 194      WS    NaN     NaN -13.58 -172.33  TOTAL  1000HAB   1.0      179727
# 195      YE    NaN     NaN  15.00   48.00  TOTAL  1000HAB   0.7    24473178
# 196      ZA    NaN     NaN -29.00   24.00  TOTAL  1000HAB   2.8    47880601
# 197      ZM    NaN     NaN -15.00   30.00  TOTAL  1000HAB   2.0    13605984
# 198      ZW    NaN     NaN -20.00   30.00  TOTAL  1000HAB   1.7    12894316
#
# ...

# %%
df[df["year"].between(2009,2012)]
# Out:
#     country  state  county   lat    lng   type  measure  beds  population  \
# 0        AF    NaN     NaN  33.0   65.0  TOTAL  1000HAB   0.5    31161376
# 2        AL    NaN     NaN  41.0   20.0  TOTAL  1000HAB   2.6     2900401
# 3        AD    NaN     NaN  42.5    1.5  TOTAL  1000HAB   2.5       84463
# 4        AE    NaN     NaN  24.0   54.0  TOTAL  1000HAB   1.1     9141596
# 5        AR    NaN     NaN -34.0  -64.0  TOTAL  1000HAB   4.7    41733271
# ..      ...    ...     ...   ...    ...    ...      ...   ...         ...
# 190      VE    NaN     NaN   8.0  -66.0  TOTAL  1000HAB   0.9    28888369
# 192      VN    NaN     NaN  16.0  106.0  TOTAL  1000HAB   2.0    87967651
# 195      YE    NaN     NaN  15.0   48.0  TOTAL  1000HAB   0.7    24473178
# 197      ZM    NaN     NaN -15.0   30.0  TOTAL  1000HAB   2.0    13605984
# 198      ZW    NaN     NaN -20.0   30.0  TOTAL  1000HAB   1.7    12894316
#
#      year      source                                    source_url
# ...

# %%
df["beds"].duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 194     True
# 195     True
# 196     True
# 197     True
# 198     True
# Name: beds, Length: 199, dtype: bool

# %%
df[df["beds"].duplicated()]
# Out:
#     country  state  county    lat     lng   type  measure  beds  population  \
# 8        AU    NaN     NaN -27.00  133.00  TOTAL  1000HAB   3.9    22031750
# 10       AZ    NaN     NaN  40.50   47.50  TOTAL  1000HAB   4.7     9295784
# 13       BJ    NaN     NaN   9.50    2.25  TOTAL  1000HAB   0.5     9199259
# 17       BH    NaN     NaN  26.00   50.55  TOTAL  1000HAB   2.1     1299943
# 21       BZ    NaN     NaN  17.25  -88.75  TOTAL  1000HAB   1.1      338000
# ..      ...    ...     ...    ...     ...    ...      ...   ...         ...
# 194      WS    NaN     NaN -13.58 -172.33  TOTAL  1000HAB   1.0      179727
# 195      YE    NaN     NaN  15.00   48.00  TOTAL  1000HAB   0.7    24473178
# 196      ZA    NaN     NaN -29.00   24.00  TOTAL  1000HAB   2.8    47880601
# 197      ZM    NaN     NaN -15.00   30.00  TOTAL  1000HAB   2.0    13605984
# 198      ZW    NaN     NaN -20.00   30.00  TOTAL  1000HAB   1.7    12894316
#
# ...

# %%
df["beds"].duplicated(keep="last")
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 194    False
# 195    False
# 196    False
# 197    False
# 198    False
# Name: beds, Length: 199, dtype: bool

# %%
df["beds"].duplicated(keep=False)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 194    True
# 195    True
# 196    True
# 197    True
# 198    True
# Name: beds, Length: 199, dtype: bool

# %%
~df["beds"].duplicated(keep=False)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 194    False
# 195    False
# 196    False
# 197    False
# 198    False
# Name: beds, Length: 199, dtype: bool

# %%
 df.drop_duplicates(subset=["year"])
# Out:
#     country  state  county    lat     lng   type  measure       beds  \
# 0        AF    NaN     NaN  33.00   65.00  TOTAL  1000HAB   0.500000
# 1        AO    NaN     NaN -12.50   18.50  TOTAL  1000HAB   0.800000
# 3        AD    NaN     NaN  42.50    1.50  TOTAL  1000HAB   2.500000
# 7        AG    NaN     NaN  17.05  -61.80  TOTAL  1000HAB   2.100000
# 8        AU    NaN     NaN -27.00  133.00  TOTAL  1000HAB   3.900000
# 22       BM    NaN     NaN  32.33  -64.75  TOTAL  1000HAB   6.300000
# 34       CI    NaN     NaN   8.00   -5.00  TOTAL  1000HAB   0.400000
# 43       KY    NaN     NaN  19.50  -80.50  TOTAL  1000HAB   3.000000
# 51       DZ    NaN     NaN  28.00    3.00  TOTAL  1000HAB   1.700000
# 72       GL    NaN     NaN  72.00  -40.00  TOTAL  1000HAB  14.353400
# 75       HK    NaN     NaN  22.25  114.17  TOTAL  1000HAB   4.890900
# 77       HR    NaN     NaN  45.17   15.50  TOTAL  1000HAB   5.890000
# 78       HT    NaN     NaN  19.00  -72.42  TOTAL  1000HAB   1.300000
# ...

# %%
df.drop_duplicates(subset=["year","beds"])
# Out:
#     country  state  county    lat     lng   type  measure   beds  population  \
# 0        AF    NaN     NaN  33.00   65.00  TOTAL  1000HAB   0.50    31161376
# 1        AO    NaN     NaN -12.50   18.50  TOTAL  1000HAB   0.80    19433602
# 2        AL    NaN     NaN  41.00   20.00  TOTAL  1000HAB   2.60     2900401
# 3        AD    NaN     NaN  42.50    1.50  TOTAL  1000HAB   2.50       84463
# 4        AE    NaN     NaN  24.00   54.00  TOTAL  1000HAB   1.10     9141596
# ..      ...    ...     ...    ...     ...    ...      ...    ...         ...
# 191      VI    NaN     NaN  18.33  -64.83  TOTAL  1000HAB  18.68      108095
# 192      VN    NaN     NaN  16.00  106.00  TOTAL  1000HAB   2.00    87967651
# 193      VU    NaN     NaN -16.00  167.00  TOTAL  1000HAB   1.70      224704
# 194      WS    NaN     NaN -13.58 -172.33  TOTAL  1000HAB   1.00      179727
# 196      ZA    NaN     NaN -29.00   24.00  TOTAL  1000HAB   2.80    47880601
#
# ...
