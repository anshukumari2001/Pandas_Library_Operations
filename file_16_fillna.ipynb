# %%
import pandas as pd

# %%
df=pd.read_csv("hospital.csv")
df
# Out:
#     country  state  county    lat     lng   type  measure  beds  population  \
# 0        AF    NaN     NaN  33.00   65.00  TOTAL  1000HAB   0.5    31161376
# 1        AO    NaN     NaN -12.50   18.50  TOTAL  1000HAB   0.8    19433602
# 2        AL    NaN     NaN  41.00   20.00  TOTAL  1000HAB   2.6     2900401
# 3        AD    NaN     NaN  42.50    1.50  TOTAL  1000HAB   2.5       84463
# 4        AE    NaN     NaN  24.00   54.00  TOTAL  1000HAB   1.1     9141596
# ..      ...    ...     ...    ...     ...    ...      ...   ...         ...
# 194      WS    NaN     NaN -13.58 -172.33  TOTAL  1000HAB   1.0      179727
# 195      YE    NaN     NaN  15.00   48.00  TOTAL  1000HAB   0.7    24473178
# 196      ZA    NaN     NaN -29.00   24.00  TOTAL  1000HAB   2.8    47880601
# 197      ZM    NaN     NaN -15.00   30.00  TOTAL  1000HAB   2.0    13605984
# 198      ZW    NaN     NaN -20.00   30.00  TOTAL  1000HAB   1.7    12894316
#
# ...

# %%
df.fillna(0)
# Out:
#     country  state  county    lat     lng   type  measure  beds  population  \
# 0        AF    0.0     0.0  33.00   65.00  TOTAL  1000HAB   0.5    31161376
# 1        AO    0.0     0.0 -12.50   18.50  TOTAL  1000HAB   0.8    19433602
# 2        AL    0.0     0.0  41.00   20.00  TOTAL  1000HAB   2.6     2900401
# 3        AD    0.0     0.0  42.50    1.50  TOTAL  1000HAB   2.5       84463
# 4        AE    0.0     0.0  24.00   54.00  TOTAL  1000HAB   1.1     9141596
# ..      ...    ...     ...    ...     ...    ...      ...   ...         ...
# 194      WS    0.0     0.0 -13.58 -172.33  TOTAL  1000HAB   1.0      179727
# 195      YE    0.0     0.0  15.00   48.00  TOTAL  1000HAB   0.7    24473178
# 196      ZA    0.0     0.0 -29.00   24.00  TOTAL  1000HAB   2.8    47880601
# 197      ZM    0.0     0.0 -15.00   30.00  TOTAL  1000HAB   2.0    13605984
# 198      ZW    0.0     0.0 -20.00   30.00  TOTAL  1000HAB   1.7    12894316
#
# ...

# %%
df["state"].fillna("Bihar",inplace=True)

# %%
df
# Out:
#     country  state  county    lat     lng   type  measure  beds  population  \
# 0        AF  Bihar     NaN  33.00   65.00  TOTAL  1000HAB   0.5    31161376
# 1        AO  Bihar     NaN -12.50   18.50  TOTAL  1000HAB   0.8    19433602
# 2        AL  Bihar     NaN  41.00   20.00  TOTAL  1000HAB   2.6     2900401
# 3        AD  Bihar     NaN  42.50    1.50  TOTAL  1000HAB   2.5       84463
# 4        AE  Bihar     NaN  24.00   54.00  TOTAL  1000HAB   1.1     9141596
# ..      ...    ...     ...    ...     ...    ...      ...   ...         ...
# 194      WS  Bihar     NaN -13.58 -172.33  TOTAL  1000HAB   1.0      179727
# 195      YE  Bihar     NaN  15.00   48.00  TOTAL  1000HAB   0.7    24473178
# 196      ZA  Bihar     NaN -29.00   24.00  TOTAL  1000HAB   2.8    47880601
# 197      ZM  Bihar     NaN -15.00   30.00  TOTAL  1000HAB   2.0    13605984
# 198      ZW  Bihar     NaN -20.00   30.00  TOTAL  1000HAB   1.7    12894316
#
# ...

# %%
df.county.fillna(1000,inplace=True)

# %%
df
# Out:
#     country  state  county    lat     lng   type  measure  beds  population  \
# 0        AF  Bihar  1000.0  33.00   65.00  TOTAL  1000HAB   0.5    31161376
# 1        AO  Bihar  1000.0 -12.50   18.50  TOTAL  1000HAB   0.8    19433602
# 2        AL  Bihar  1000.0  41.00   20.00  TOTAL  1000HAB   2.6     2900401
# 3        AD  Bihar  1000.0  42.50    1.50  TOTAL  1000HAB   2.5       84463
# 4        AE  Bihar  1000.0  24.00   54.00  TOTAL  1000HAB   1.1     9141596
# ..      ...    ...     ...    ...     ...    ...      ...   ...         ...
# 194      WS  Bihar  1000.0 -13.58 -172.33  TOTAL  1000HAB   1.0      179727
# 195      YE  Bihar  1000.0  15.00   48.00  TOTAL  1000HAB   0.7    24473178
# 196      ZA  Bihar  1000.0 -29.00   24.00  TOTAL  1000HAB   2.8    47880601
# 197      ZM  Bihar  1000.0 -15.00   30.00  TOTAL  1000HAB   2.0    13605984
# 198      ZW  Bihar  1000.0 -20.00   30.00  TOTAL  1000HAB   1.7    12894316
#
# ...
