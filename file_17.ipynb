# %%
import pandas as pd

# %%
df=pd.read_csv("hospital.csv")
df
# Out:
#     country  state  county    lat     lng   type  measure  beds  population  \
# 0        AF    NaN     NaN  33.00   65.00  TOTAL  1000HAB   0.5    31161376
# 1        AO    NaN     NaN -12.50   18.50  TOTAL  1000HAB   0.8    19433602
# 2        AL    NaN     NaN  41.00   20.00  TOTAL  1000HAB   2.6     2900401
# 3        AD    NaN     NaN  42.50    1.50  TOTAL  1000HAB   2.5       84463
# 4        AE    NaN     NaN  24.00   54.00  TOTAL  1000HAB   1.1     9141596
# ..      ...    ...     ...    ...     ...    ...      ...   ...         ...
# 194      WS    NaN     NaN -13.58 -172.33  TOTAL  1000HAB   1.0      179727
# 195      YE    NaN     NaN  15.00   48.00  TOTAL  1000HAB   0.7    24473178
# 196      ZA    NaN     NaN -29.00   24.00  TOTAL  1000HAB   2.8    47880601
# 197      ZM    NaN     NaN -15.00   30.00  TOTAL  1000HAB   2.0    13605984
# 198      ZW    NaN     NaN -20.00   30.00  TOTAL  1000HAB   1.7    12894316
#
# ...

# %%
df.sort_values("country")
# Out:
#     country  state  county    lat   lng   type  measure  beds  population  \
# 3        AD    NaN     NaN  42.50   1.5  TOTAL  1000HAB   2.5       84463
# 4        AE    NaN     NaN  24.00  54.0  TOTAL  1000HAB   1.1     9141596
# 0        AF    NaN     NaN  33.00  65.0  TOTAL  1000HAB   0.5    31161376
# 7        AG    NaN     NaN  17.05 -61.8  TOTAL  1000HAB   2.1       89253
# 2        AL    NaN     NaN  41.00  20.0  TOTAL  1000HAB   2.6     2900401
# ..      ...    ...     ...    ...   ...    ...      ...   ...         ...
# 195      YE    NaN     NaN  15.00  48.0  TOTAL  1000HAB   0.7    24473178
# 196      ZA    NaN     NaN -29.00  24.0  TOTAL  1000HAB   2.8    47880601
# 197      ZM    NaN     NaN -15.00  30.0  TOTAL  1000HAB   2.0    13605984
# 198      ZW    NaN     NaN -20.00  30.0  TOTAL  1000HAB   1.7    12894316
# 128     NaN    NaN     NaN -22.00  17.0  TOTAL  1000HAB   2.7     2081044
#
#      year      source                                    source_url
# ...

# %%
df.sort_values("country",ascending=False)
# Out:
#     country  state  county    lat     lng   type  measure  beds  population  \
# 198      ZW    NaN     NaN -20.00   30.00  TOTAL  1000HAB   1.7    12894316
# 197      ZM    NaN     NaN -15.00   30.00  TOTAL  1000HAB   2.0    13605984
# 196      ZA    NaN     NaN -29.00   24.00  TOTAL  1000HAB   2.8    47880601
# 195      YE    NaN     NaN  15.00   48.00  TOTAL  1000HAB   0.7    24473178
# 194      WS    NaN     NaN -13.58 -172.33  TOTAL  1000HAB   1.0      179727
# ..      ...    ...     ...    ...     ...    ...      ...   ...         ...
# 7        AG    NaN     NaN  17.05  -61.80  TOTAL  1000HAB   2.1       89253
# 0        AF    NaN     NaN  33.00   65.00  TOTAL  1000HAB   0.5    31161376
# 4        AE    NaN     NaN  24.00   54.00  TOTAL  1000HAB   1.1     9141596
# 3        AD    NaN     NaN  42.50    1.50  TOTAL  1000HAB   2.5       84463
# 128     NaN    NaN     NaN -22.00   17.00  TOTAL  1000HAB   2.7     2081044
#
# ...

# %%
df.sort_values("country",inplace=True)

# %%
df.sort_values("beds")
# Out:
#     country  state  county    lat     lng   type  measure     beds  \
# 83       IR    NaN     NaN  32.00   53.00  TOTAL  1000HAB   0.1000
# 118      ML    NaN     NaN  17.00   -4.00  TOTAL  1000HAB   0.1000
# 113      MG    NaN     NaN -20.00   47.00  TOTAL  1000HAB   0.2000
# 66       GN    NaN     NaN  11.00  -10.00  TOTAL  1000HAB   0.3000
# 129      NE    NaN     NaN  16.00    8.00  TOTAL  1000HAB   0.3000
# ..      ...    ...     ...    ...     ...    ...      ...      ...
# 146      KP    NaN     NaN  40.00  127.00  TOTAL  1000HAB  13.2000
# 90       JP    NaN     NaN  36.00  138.00  TOTAL  1000HAB  13.7000
# 111      MC    NaN     NaN  43.73    7.40  TOTAL  1000HAB  13.8000
# 72       GL    NaN     NaN  72.00  -40.00  TOTAL  1000HAB  14.3534
# 191      VI    NaN     NaN  18.33  -64.83  TOTAL  1000HAB  18.6800
#
#      population  year      source  \
# 83     75539862  2012  world-bank
# 118    15049353  2010  world-bank
# 113    21151640  2010  world-bank
# ...

# %%
df.sort_values(["country","beds"])
# Out:
#     country  state  county    lat   lng   type  measure  beds  population  \
# 3        AD    NaN     NaN  42.50   1.5  TOTAL  1000HAB   2.5       84463
# 4        AE    NaN     NaN  24.00  54.0  TOTAL  1000HAB   1.1     9141596
# 0        AF    NaN     NaN  33.00  65.0  TOTAL  1000HAB   0.5    31161376
# 7        AG    NaN     NaN  17.05 -61.8  TOTAL  1000HAB   2.1       89253
# 2        AL    NaN     NaN  41.00  20.0  TOTAL  1000HAB   2.6     2900401
# ..      ...    ...     ...    ...   ...    ...      ...   ...         ...
# 195      YE    NaN     NaN  15.00  48.0  TOTAL  1000HAB   0.7    24473178
# 196      ZA    NaN     NaN -29.00  24.0  TOTAL  1000HAB   2.8    47880601
# 197      ZM    NaN     NaN -15.00  30.0  TOTAL  1000HAB   2.0    13605984
# 198      ZW    NaN     NaN -20.00  30.0  TOTAL  1000HAB   1.7    12894316
# 128     NaN    NaN     NaN -22.00  17.0  TOTAL  1000HAB   2.7     2081044
#
#      year      source                                    source_url
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199 entries, 3 to 128
# Data columns (total 12 columns):
# country       198 non-null object
# state         0 non-null float64
# county        0 non-null float64
# lat           199 non-null float64
# lng           199 non-null float64
# type          199 non-null object
# measure       199 non-null object
# beds          199 non-null float64
# population    199 non-null int64
# year          199 non-null int64
# source        199 non-null object
# source_url    199 non-null object
# dtypes: float64(5), int64(2), object(5)
# memory usage: 20.2+ KB

# %%
df["beds"].rank().head()
# Out:
# 3    102.0
# 4     45.0
# 0     15.0
# 7     89.5
# 2    105.0
# Name: beds, dtype: float64

# %%
df.insert(8,"Rank_beds",df["beds"].rank())

# %%
df
# Out:
#     country  state  county    lat   lng   type  measure  beds  Rank_beds  \
# 3        AD    NaN     NaN  42.50   1.5  TOTAL  1000HAB   2.5      102.0
# 4        AE    NaN     NaN  24.00  54.0  TOTAL  1000HAB   1.1       45.0
# 0        AF    NaN     NaN  33.00  65.0  TOTAL  1000HAB   0.5       15.0
# 7        AG    NaN     NaN  17.05 -61.8  TOTAL  1000HAB   2.1       89.5
# 2        AL    NaN     NaN  41.00  20.0  TOTAL  1000HAB   2.6      105.0
# ..      ...    ...     ...    ...   ...    ...      ...   ...        ...
# 195      YE    NaN     NaN  15.00  48.0  TOTAL  1000HAB   0.7       25.5
# 196      ZA    NaN     NaN -29.00  24.0  TOTAL  1000HAB   2.8      112.5
# 197      ZM    NaN     NaN -15.00  30.0  TOTAL  1000HAB   2.0       82.5
# 198      ZW    NaN     NaN -20.00  30.0  TOTAL  1000HAB   1.7       72.5
# 128     NaN    NaN     NaN -22.00  17.0  TOTAL  1000HAB   2.7      109.0
#
#      population  year      source  \
# 3         84463  2009  world-bank
# ...

# %%
df.sort_values("beds")
# Out:
#     country  state  county    lat     lng   type  measure     beds  Rank_beds  \
# 83       IR    NaN     NaN  32.00   53.00  TOTAL  1000HAB   0.1000        1.5
# 118      ML    NaN     NaN  17.00   -4.00  TOTAL  1000HAB   0.1000        1.5
# 113      MG    NaN     NaN -20.00   47.00  TOTAL  1000HAB   0.2000        3.0
# 66       GN    NaN     NaN  11.00  -10.00  TOTAL  1000HAB   0.3000        5.0
# 129      NE    NaN     NaN  16.00    8.00  TOTAL  1000HAB   0.3000        5.0
# ..      ...    ...     ...    ...     ...    ...      ...      ...        ...
# 146      KP    NaN     NaN  40.00  127.00  TOTAL  1000HAB  13.2000      195.0
# 90       JP    NaN     NaN  36.00  138.00  TOTAL  1000HAB  13.7000      196.0
# 111      MC    NaN     NaN  43.73    7.40  TOTAL  1000HAB  13.8000      197.0
# 72       GL    NaN     NaN  72.00  -40.00  TOTAL  1000HAB  14.3534      198.0
# 191      VI    NaN     NaN  18.33  -64.83  TOTAL  1000HAB  18.6800      199.0
#
# ...
