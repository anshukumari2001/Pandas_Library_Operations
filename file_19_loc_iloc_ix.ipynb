# %%
import pandas as pd

# %%
df= pd.read_csv("hospital.csv",index_col="country")

# %%
df
# Out:
#          state  county    lat     lng   type  measure  beds  population  year  \
# country
# AF         NaN     NaN  33.00   65.00  TOTAL  1000HAB   0.5    31161376  2012
# AO         NaN     NaN -12.50   18.50  TOTAL  1000HAB   0.8    19433602  2005
# AL         NaN     NaN  41.00   20.00  TOTAL  1000HAB   2.6     2900401  2012
# AD         NaN     NaN  42.50    1.50  TOTAL  1000HAB   2.5       84463  2009
# AE         NaN     NaN  24.00   54.00  TOTAL  1000HAB   1.1     9141596  2012
# ...        ...     ...    ...     ...    ...      ...   ...         ...   ...
# WS         NaN     NaN -13.58 -172.33  TOTAL  1000HAB   1.0      179727  2005
# YE         NaN     NaN  15.00   48.00  TOTAL  1000HAB   0.7    24473178  2012
# ZA         NaN     NaN -29.00   24.00  TOTAL  1000HAB   2.8    47880601  2005
# ZM         NaN     NaN -15.00   30.00  TOTAL  1000HAB   2.0    13605984  2010
# ZW         NaN     NaN -20.00   30.00  TOTAL  1000HAB   1.7    12894316  2011
#
# ...

# %%
df.sort_index(inplace=True)

# %%
df
# Out:
#          state  county    lat   lng   type  measure  beds  population  year  \
# country
# AD         NaN     NaN  42.50   1.5  TOTAL  1000HAB   2.5       84463  2009
# AE         NaN     NaN  24.00  54.0  TOTAL  1000HAB   1.1     9141596  2012
# AF         NaN     NaN  33.00  65.0  TOTAL  1000HAB   0.5    31161376  2012
# AG         NaN     NaN  17.05 -61.8  TOTAL  1000HAB   2.1       89253  2011
# AL         NaN     NaN  41.00  20.0  TOTAL  1000HAB   2.6     2900401  2012
# ...        ...     ...    ...   ...    ...      ...   ...         ...   ...
# YE         NaN     NaN  15.00  48.0  TOTAL  1000HAB   0.7    24473178  2012
# ZA         NaN     NaN -29.00  24.0  TOTAL  1000HAB   2.8    47880601  2005
# ZM         NaN     NaN -15.00  30.0  TOTAL  1000HAB   2.0    13605984  2010
# ZW         NaN     NaN -20.00  30.0  TOTAL  1000HAB   1.7    12894316  2011
# NaN        NaN     NaN -22.00  17.0  TOTAL  1000HAB   2.7     2081044  2009
#
# ...

# %%
df.loc["AE"]
# Out:
# state                                                  NaN
# county                                                 NaN
# lat                                                     24
# lng                                                     54
# type                                                 TOTAL
# measure                                            1000HAB
# beds                                                   1.1
# population                                         9141596
# year                                                  2012
# source                                          world-bank
# source_url    https://datahub.io/world-bank/sh.med.beds.zs
# Name: AE, dtype: object

# %%
df.loc["YE","beds"]
# Out:
# 0.7

# %%
df.loc[["AE","YE"]]
# Out:
#          state  county   lat   lng   type  measure  beds  population  year  \
# country
# AE         NaN     NaN  24.0  54.0  TOTAL  1000HAB   1.1     9141596  2012
# YE         NaN     NaN  15.0  48.0  TOTAL  1000HAB   0.7    24473178  2012
#
#              source                                    source_url
# country
# AE       world-bank  https://datahub.io/world-bank/sh.med.beds.zs
# YE       world-bank  https://datahub.io/world-bank/sh.med.beds.zs

# %%
df.iloc[1]
# Out:
# state                                                  NaN
# county                                                 NaN
# lat                                                     24
# lng                                                     54
# type                                                 TOTAL
# measure                                            1000HAB
# beds                                                   1.1
# population                                         9141596
# year                                                  2012
# source                                          world-bank
# source_url    https://datahub.io/world-bank/sh.med.beds.zs
# Name: AE, dtype: object

# %%
df.iloc[2:5]
# Out:
#          state  county    lat   lng   type  measure  beds  population  year  \
# country
# AF         NaN     NaN  33.00  65.0  TOTAL  1000HAB   0.5    31161376  2012
# AG         NaN     NaN  17.05 -61.8  TOTAL  1000HAB   2.1       89253  2011
# AL         NaN     NaN  41.00  20.0  TOTAL  1000HAB   2.6     2900401  2012
#
#              source                                    source_url
# country
# AF       world-bank  https://datahub.io/world-bank/sh.med.beds.zs
# AG       world-bank  https://datahub.io/world-bank/sh.med.beds.zs
# AL       world-bank  https://datahub.io/world-bank/sh.med.beds.zs

# %%
df.ix["AE":"AG"]
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#          state  county    lat   lng   type  measure  beds  population  year  \
# country
# AE         NaN     NaN  24.00  54.0  TOTAL  1000HAB   1.1     9141596  2012
# AF         NaN     NaN  33.00  65.0  TOTAL  1000HAB   0.5    31161376  2012
# AG         NaN     NaN  17.05 -61.8  TOTAL  1000HAB   2.1       89253  2011
#
#              source                                    source_url
# country
# AE       world-bank  https://datahub.io/world-bank/sh.med.beds.zs
# AF       world-bank  https://datahub.io/world-bank/sh.med.beds.zs
# AG       world-bank  https://datahub.io/world-bank/sh.med.beds.zs

# %%
df.ix[3:7]
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#          state  county    lat   lng   type  measure  beds  population  year  \
# country
# AG         NaN     NaN  17.05 -61.8  TOTAL  1000HAB   2.1       89253  2011
# AL         NaN     NaN  41.00  20.0  TOTAL  1000HAB   2.6     2900401  2012
# AM         NaN     NaN  40.00  45.0  TOTAL  1000HAB   3.9     2884229  2012
# AO         NaN     NaN -12.50  18.5  TOTAL  1000HAB   0.8    19433602  2005
#
#              source                                    source_url
# country
# AG       world-bank  https://datahub.io/world-bank/sh.med.beds.zs
# AL       world-bank  https://datahub.io/world-bank/sh.med.beds.zs
# ...

# %%
df.ix["AE","beds"]=2.1
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#          state  county    lat   lng   type  measure  beds  population  year  \
# country
# AD         NaN     NaN  42.50   1.5  TOTAL  1000HAB   2.5       84463  2009
# AE         NaN     NaN  24.00  54.0  TOTAL  1000HAB   2.1     9141596  2012
# AF         NaN     NaN  33.00  65.0  TOTAL  1000HAB   0.5    31161376  2012
# AG         NaN     NaN  17.05 -61.8  TOTAL  1000HAB   2.1       89253  2011
# AL         NaN     NaN  41.00  20.0  TOTAL  1000HAB   2.6     2900401  2012
# ...        ...     ...    ...   ...    ...      ...   ...         ...   ...
# YE         NaN     NaN  15.00  48.0  TOTAL  1000HAB   0.7    24473178  2012
# ZA         NaN     NaN -29.00  24.0  TOTAL  1000HAB   2.8    47880601  2005
# ZM         NaN     NaN -15.00  30.0  TOTAL  1000HAB   2.0    13605984  2010
# ZW         NaN     NaN -20.00  30.0  TOTAL  1000HAB   1.7    12894316  2011
# NaN        NaN     NaN -22.00  17.0  TOTAL  1000HAB   2.7     2081044  2009
#
# ...

# %%
df.ix["AE",["beds","population"]]= [2.1,10000]
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#          state  county    lat   lng   type  measure  beds  population  year  \
# country
# AD         NaN     NaN  42.50   1.5  TOTAL  1000HAB   2.5       84463  2009
# AE         NaN     NaN  24.00  54.0  TOTAL  1000HAB   2.1       10000  2012
# AF         NaN     NaN  33.00  65.0  TOTAL  1000HAB   0.5    31161376  2012
# AG         NaN     NaN  17.05 -61.8  TOTAL  1000HAB   2.1       89253  2011
# AL         NaN     NaN  41.00  20.0  TOTAL  1000HAB   2.6     2900401  2012
#
#              source                                    source_url
# country
# AD       world-bank  https://datahub.io/world-bank/sh.med.beds.zs
# AE       world-bank  https://datahub.io/world-bank/sh.med.beds.zs
# AF       world-bank  https://datahub.io/world-bank/sh.med.beds.zs
# AG       world-bank  https://datahub.io/world-bank/sh.med.beds.zs
# AL       world-bank  https://datahub.io/world-bank/sh.med.beds.zs

# %%
df[df["beds"]==2.5]
# Out:
#          state  county   lat   lng   type  measure  beds  population  year  \
# country
# AD         NaN     NaN  42.5   1.5  TOTAL  1000HAB   2.5       84463  2009
# TR         NaN     NaN  39.0  35.0  TOTAL  1000HAB   2.5    73443863  2011
# UY         NaN     NaN -33.0 -56.0  TOTAL  1000HAB   2.5     3378974  2012
#
#              source                                    source_url
# country
# AD       world-bank  https://datahub.io/world-bank/sh.med.beds.zs
# TR       world-bank  https://datahub.io/world-bank/sh.med.beds.zs
# UY       world-bank  https://datahub.io/world-bank/sh.med.beds.zs

# %%
df.rename(columns={"year":"Released Year","source":"Income source"})
# Out:
#          state  county    lat   lng   type  measure  beds  population  \
# country
# AD         NaN     NaN  42.50   1.5  TOTAL  1000HAB   2.5       84463
# AE         NaN     NaN  24.00  54.0  TOTAL  1000HAB   2.1       10000
# AF         NaN     NaN  33.00  65.0  TOTAL  1000HAB   0.5    31161376
# AG         NaN     NaN  17.05 -61.8  TOTAL  1000HAB   2.1       89253
# AL         NaN     NaN  41.00  20.0  TOTAL  1000HAB   2.6     2900401
# ...        ...     ...    ...   ...    ...      ...   ...         ...
# YE         NaN     NaN  15.00  48.0  TOTAL  1000HAB   0.7    24473178
# ZA         NaN     NaN -29.00  24.0  TOTAL  1000HAB   2.8    47880601
# ZM         NaN     NaN -15.00  30.0  TOTAL  1000HAB   2.0    13605984
# ZW         NaN     NaN -20.00  30.0  TOTAL  1000HAB   1.7    12894316
# NaN        NaN     NaN -22.00  17.0  TOTAL  1000HAB   2.7     2081044
#
#          Released Year Income source  \
# country
# AD                2009    world-bank
# ...

# %%
df.rename(index={"AD":"ad","AL":"al"})
# Out:
#          state  county    lat   lng   type  measure  beds  population  year  \
# country
# ad         NaN     NaN  42.50   1.5  TOTAL  1000HAB   2.5       84463  2009
# AE         NaN     NaN  24.00  54.0  TOTAL  1000HAB   2.1       10000  2012
# AF         NaN     NaN  33.00  65.0  TOTAL  1000HAB   0.5    31161376  2012
# AG         NaN     NaN  17.05 -61.8  TOTAL  1000HAB   2.1       89253  2011
# al         NaN     NaN  41.00  20.0  TOTAL  1000HAB   2.6     2900401  2012
# ...        ...     ...    ...   ...    ...      ...   ...         ...   ...
# YE         NaN     NaN  15.00  48.0  TOTAL  1000HAB   0.7    24473178  2012
# ZA         NaN     NaN -29.00  24.0  TOTAL  1000HAB   2.8    47880601  2005
# ZM         NaN     NaN -15.00  30.0  TOTAL  1000HAB   2.0    13605984  2010
# ZW         NaN     NaN -20.00  30.0  TOTAL  1000HAB   1.7    12894316  2011
# NaN        NaN     NaN -22.00  17.0  TOTAL  1000HAB   2.7     2081044  2009
#
# ...
